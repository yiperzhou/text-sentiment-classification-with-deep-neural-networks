# %%
from pyspark.sql import SparkSession
import json

# %%
spark = SparkSession.builder.appName("statistics for hotels reviews in Booking").config(
    "spark.some.config.option", "booking").getOrCreate()

# %%
spark

# %%
data = spark.read.json("/home/yi/006_Paris_tripadvisor.json")

# %%
data.printSchema()
# Out:
# root
#  |-- _id: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- hotelLocation: string (nullable = true)
#  |-- hotelName: string (nullable = true)
#  |-- hotelStars: string (nullable = true)
#  |-- hotelUrl: string (nullable = true)
#  |-- review: string (nullable = true)
#  |-- score: double (nullable = true)
#  |-- title: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
data.count()
# Out:
# 349413

# %%
# try tp remove duplicate rows in data

data = data.drop_duplicates()

# %%
data.count()
# Out:
# 349413

# %%
statistics = dict()
statistics["totalReviews"] = data.select(data.url).distinct().count()

# %%
statistics
# Out:
# {'totalReviews': 198783}

# %%
statistics["totalHotels"] = data.select(data.hotelUrl).distinct().count()

# %%
statistics["avgReviewNumAHotel"] =  statistics["totalReviews"] / statistics["totalHotels"]

# %%
statistics["0 stars"] = 0
statistics["1 stars"] = 0
statistics["2 stars"] = 0
statistics["3 stars"] = 0
statistics["4 stars"] = 0
statistics["5 stars"] = 0
statistics["null stars"] = 0
statistics["eachHotelDetail"]  = list()
statistics["minReviewNumAHotel"] = statistics["totalReviews"]
statistics["maxReviewNumAHotel"] = 0

# %%
nullScoreNumAHotel = 0
nullScoreNum = 0
totalScoreAHotel = 0
totalScore = 0
# get statistics for each single hotel
for row in data.groupby(data.hotelUrl).count().collect():
    oneHotel = dict()
    oneHotel["reviewsNum"] = row["count"]
#     print(oneHotel["reviewsNum"])
    if oneHotel["reviewsNum"] > statistics["maxReviewNumAHotel"]:
        statistics["maxReviewNumAHotel"] = oneHotel["reviewsNum"]
    if oneHotel["reviewsNum"] < statistics["minReviewNumAHotel"]:
        statistics["minReviewNumAHotel"] = oneHotel["reviewsNum"]
    oneHotel["hotelUrl"] = row["hotelUrl"]
    try:
        oneHotel["hotelStars"] = data.filter(data.hotelUrl == row["hotelUrl"]).first()["hotelStars"]
    except:
        oneHotel["hotelStars"] = None
    oneHotel["0 stars"] = 0
    oneHotel["1 stars"] = 0
    oneHotel["2 stars"] = 0
    oneHotel["3 stars"] = 0
    oneHotel["4 stars"] = 0
    oneHotel["5 stars"] = 0
    
    for record in data.filter(data.hotelUrl == row["hotelUrl"]).collect():
        if record["score"] == None:
            nullScoreNumAHotel += 1
            nullScoreNum += 1
        else:
#             remove \n newline and convert string into float
            try:
                totalScore += float(record["score"])
                totalScoreAHotel += float(record["score"])
            except:
                nullScoreNumAHotel += 1
                nullScoreNum += 1
                pass
#             apply Department of Tourism (DOT) Star Grading System;
# 5 stars - (0.85, 10]; 4 stars - (0.7, 0.85]; 3 stars - (0.55, 0.7]; 2 stars - (0.4, 0.55]; 1 stars - (0.25, 0.4]
# method: score/10*5; then round.
            oneHotel[str(round(float(record["score"])/10 * 5)) + " stars"] += 1
            statistics[str(round(float(record["score"])/10 * 5)) + " stars"] += 1
    if (oneHotel["reviewsNum"] - nullScoreNumAHotel) == 0:
        oneHotel["avgScore"] = None #means all reviews aren't gaven scores.
    else:
        oneHotel["avgScore"] = totalScoreAHotel / (oneHotel["reviewsNum"] - nullScoreNumAHotel)
    nullScoreNumAHotel = 0
    statistics["eachHotelDetail"].append(oneHotel)
statistics["null stars"] = nullScoreNum
statistics["avgScore"] = totalScore / (statistics["totalReviews"] - nullScoreNum)

# %%
statistics
# Out:
# {'0 stars': 0,
#  '1 stars': 198,
#  '2 stars': 1652,
#  '3 stars': 4252,
#  '4 stars': 17069,
#  '5 stars': 4772,
#  'avgReviewNumAHotel': 172.05839416058393,
#  'avgScore': 7.690363552691853,
#  'eachHotelDetail': [{'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 7,
#    '3 stars': 25,
#    '4 stars': 133,
#    '5 stars': 27,
#    'avgScore': 7.850259067357507,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/accome-apartments-parliament.html',
#    'reviewsNum': 203},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 4,
#    '3 stars': 17,
#    '4 stars': 100,
#    '5 stars': 48,
#    'avgScore': 17.071597633136086,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/swhotelkamphelsinki.html',
#    'reviewsNum': 203},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 6,
#    '3 stars': 6,
#    '4 stars': 85,
#    '5 stars': 30,
#    'avgScore': 30.925984251968522,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/the-yard-hostel-helsinki.html',
#    'reviewsNum': 173},
#   {'0 stars': 0,
#    '1 stars': 4,
#    '2 stars': 13,
#    '3 stars': 58,
#    '4 stars': 330,
#    '5 stars': 110,
#    'avgScore': 15.582718446601957,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/glo.html',
#    'reviewsNum': 556},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 4,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 1153.7428571428584,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/downtown-studio-helsinki.html',
#    'reviewsNum': 7},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 1,
#    '5 stars': 0,
#    'avgScore': 8084.500000000008,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/cozy-casa-lauttasaari.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 5,
#    '2 stars': 23,
#    '3 stars': 44,
#    '4 stars': 135,
#    '5 stars': 38,
#    'avgScore': 40.333061224489754,
#    'hotelStars': '2 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kongressikoti.html',
#    'reviewsNum': 251},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 5,
#    '3 stars': 21,
#    '4 stars': 85,
#    '5 stars': 35,
#    'avgScore': 75.09999999999984,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hotel-rantapuisto.html',
#    'reviewsNum': 160},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 5,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 1233.2222222222192,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hostel-auris.html',
#    'reviewsNum': 12},
#   {'0 stars': 0,
#    '1 stars': 5,
#    '2 stars': 58,
#    '3 stars': 96,
#    '4 stars': 328,
#    '5 stars': 74,
#    'avgScore': 27.203565062388428,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/radisson-sas-seaside.html',
#    'reviewsNum': 588},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 8,
#    '4 stars': 64,
#    '5 stars': 20,
#    'avgScore': 172.24301075268704,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/huoneistohotelli-gella-oy.html',
#    'reviewsNum': 106},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 2,
#    'avgScore': 4013.424999999974,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/guest-house-stranda.html',
#    'reviewsNum': 5},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 7,
#    '3 stars': 25,
#    '4 stars': 133,
#    '5 stars': 27,
#    'avgScore': 7.850259067357507,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/accome-apartments-parliament.html',
#    'reviewsNum': 203},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 4,
#    '3 stars': 17,
#    '4 stars': 100,
#    '5 stars': 48,
#    'avgScore': 17.071597633136086,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/swhotelkamphelsinki.html',
#    'reviewsNum': 203},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 6,
#    '3 stars': 6,
#    '4 stars': 85,
#    '5 stars': 30,
#    'avgScore': 30.925984251968522,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/the-yard-hostel-helsinki.html',
#    'reviewsNum': 173},
#   {'0 stars': 0,
#    '1 stars': 4,
#    '2 stars': 13,
#    '3 stars': 58,
#    '4 stars': 330,
#    '5 stars': 110,
#    'avgScore': 15.582718446601957,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/glo.html',
#    'reviewsNum': 556},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 4,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 1153.7428571428584,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/downtown-studio-helsinki.html',
#    'reviewsNum': 7},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 1,
#    '5 stars': 0,
#    'avgScore': 8084.500000000008,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/cozy-casa-lauttasaari.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 5,
#    '2 stars': 23,
#    '3 stars': 44,
#    '4 stars': 135,
#    '5 stars': 38,
#    'avgScore': 40.333061224489754,
#    'hotelStars': '2 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kongressikoti.html',
#    'reviewsNum': 251},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 5,
#    '3 stars': 21,
#    '4 stars': 85,
#    '5 stars': 35,
#    'avgScore': 75.09999999999984,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hotel-rantapuisto.html',
#    'reviewsNum': 160},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 5,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 1233.2222222222192,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hostel-auris.html',
#    'reviewsNum': 12},
#   {'0 stars': 0,
#    '1 stars': 5,
#    '2 stars': 58,
#    '3 stars': 96,
#    '4 stars': 328,
#    '5 stars': 74,
#    'avgScore': 27.203565062388428,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/radisson-sas-seaside.html',
#    'reviewsNum': 588},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 8,
#    '4 stars': 64,
#    '5 stars': 20,
#    'avgScore': 172.24301075268704,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/huoneistohotelli-gella-oy.html',
#    'reviewsNum': 106},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 2,
#    'avgScore': 4013.424999999974,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/guest-house-stranda.html',
#    'reviewsNum': 5},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 7,
#    '3 stars': 25,
#    '4 stars': 133,
#    '5 stars': 27,
#    'avgScore': 7.850259067357507,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/accome-apartments-parliament.html',
#    'reviewsNum': 203},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 4,
#    '3 stars': 17,
#    '4 stars': 100,
#    '5 stars': 48,
#    'avgScore': 17.071597633136086,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/swhotelkamphelsinki.html',
#    'reviewsNum': 203},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 6,
#    '3 stars': 6,
#    '4 stars': 85,
#    '5 stars': 30,
#    'avgScore': 30.925984251968522,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/the-yard-hostel-helsinki.html',
#    'reviewsNum': 173},
#   {'0 stars': 0,
#    '1 stars': 4,
#    '2 stars': 13,
#    '3 stars': 58,
#    '4 stars': 330,
#    '5 stars': 110,
#    'avgScore': 15.582718446601957,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/glo.html',
#    'reviewsNum': 556},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 4,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 1153.7428571428584,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/downtown-studio-helsinki.html',
#    'reviewsNum': 7},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 1,
#    '5 stars': 0,
#    'avgScore': 8084.500000000008,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/cozy-casa-lauttasaari.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 5,
#    '2 stars': 23,
#    '3 stars': 44,
#    '4 stars': 135,
#    '5 stars': 38,
#    'avgScore': 40.333061224489754,
#    'hotelStars': '2 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kongressikoti.html',
#    'reviewsNum': 251},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 5,
#    '3 stars': 21,
#    '4 stars': 85,
#    '5 stars': 35,
#    'avgScore': 75.09999999999984,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hotel-rantapuisto.html',
#    'reviewsNum': 160},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 5,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 1233.2222222222192,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hostel-auris.html',
#    'reviewsNum': 12},
#   {'0 stars': 0,
#    '1 stars': 5,
#    '2 stars': 58,
#    '3 stars': 96,
#    '4 stars': 328,
#    '5 stars': 74,
#    'avgScore': 27.203565062388428,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/radisson-sas-seaside.html',
#    'reviewsNum': 588},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 8,
#    '4 stars': 64,
#    '5 stars': 20,
#    'avgScore': 172.24301075268704,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/huoneistohotelli-gella-oy.html',
#    'reviewsNum': 106},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 2,
#    'avgScore': 4013.424999999974,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/guest-house-stranda.html',
#    'reviewsNum': 5},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 7,
#    '3 stars': 25,
#    '4 stars': 133,
#    '5 stars': 27,
#    'avgScore': 7.850259067357507,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/accome-apartments-parliament.html',
#    'reviewsNum': 203},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 4,
#    '3 stars': 17,
#    '4 stars': 100,
#    '5 stars': 48,
#    'avgScore': 17.071597633136086,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/swhotelkamphelsinki.html',
#    'reviewsNum': 203},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 6,
#    '3 stars': 6,
#    '4 stars': 85,
#    '5 stars': 30,
#    'avgScore': 30.925984251968522,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/the-yard-hostel-helsinki.html',
#    'reviewsNum': 173},
#   {'0 stars': 0,
#    '1 stars': 4,
#    '2 stars': 13,
#    '3 stars': 58,
#    '4 stars': 330,
#    '5 stars': 110,
#    'avgScore': 15.582718446601957,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/glo.html',
#    'reviewsNum': 556},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 4,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 1153.7428571428584,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/downtown-studio-helsinki.html',
#    'reviewsNum': 7},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 1,
#    '5 stars': 0,
#    'avgScore': 8084.500000000008,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/cozy-casa-lauttasaari.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 5,
#    '2 stars': 23,
#    '3 stars': 44,
#    '4 stars': 135,
#    '5 stars': 38,
#    'avgScore': 40.333061224489754,
#    'hotelStars': '2 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kongressikoti.html',
#    'reviewsNum': 251},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 5,
#    '3 stars': 21,
#    '4 stars': 85,
#    '5 stars': 35,
#    'avgScore': 75.09999999999984,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hotel-rantapuisto.html',
#    'reviewsNum': 160},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 5,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 1233.2222222222192,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hostel-auris.html',
#    'reviewsNum': 12},
#   {'0 stars': 0,
#    '1 stars': 5,
#    '2 stars': 58,
#    '3 stars': 96,
#    '4 stars': 328,
#    '5 stars': 74,
#    'avgScore': 27.203565062388428,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/radisson-sas-seaside.html',
#    'reviewsNum': 588},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 8,
#    '4 stars': 64,
#    '5 stars': 20,
#    'avgScore': 172.24301075268704,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/huoneistohotelli-gella-oy.html',
#    'reviewsNum': 106},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 2,
#    'avgScore': 4013.424999999974,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/guest-house-stranda.html',
#    'reviewsNum': 5},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 0,
#    '5 stars': 0,
#    'avgScore': None,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kallio-apartment.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 4,
#    '3 stars': 20,
#    '4 stars': 83,
#    '5 stars': 15,
#    'avgScore': 138.24390243902332,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/radisson-aleksanteri.html',
#    'reviewsNum': 134},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 15,
#    '3 stars': 57,
#    '4 stars': 151,
#    '5 stars': 27,
#    'avgScore': 75.15219123505919,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/forenom-pop-up.html',
#    'reviewsNum': 262},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 2,
#    '3 stars': 0,
#    '4 stars': 0,
#    '5 stars': 0,
#    'avgScore': 6290.766666666619,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/haapaniemenkatu-apartment.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 7,
#    '3 stars': 26,
#    '4 stars': 156,
#    '5 stars': 24,
#    'avgScore': 95.9855140186908,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hotelanna.html',
#    'reviewsNum': 223},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 5,
#    '3 stars': 1,
#    '4 stars': 10,
#    '5 stars': 2,
#    'avgScore': 1087.999999999991,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/4pillowsapartments-malminkatu.html',
#    'reviewsNum': 20},
#   {'0 stars': 0,
#    '1 stars': 3,
#    '2 stars': 3,
#    '3 stars': 19,
#    '4 stars': 74,
#    '5 stars': 95,
#    'avgScore': 114.96237113401996,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/aallonkoti.html',
#    'reviewsNum': 303},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 1,
#    '4 stars': 0,
#    '5 stars': 0,
#    'avgScore': 22308.499999999873,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/helsinki-homes.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 1,
#    '4 stars': 4,
#    '5 stars': 0,
#    'avgScore': 3725.233333333312,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/seaside-downtown-apartment.html',
#    'reviewsNum': 7},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 5,
#    '4 stars': 8,
#    '5 stars': 2,
#    'avgScore': 1497.4933333333252,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/rooftop-apartment-with-sauna.html',
#    'reviewsNum': 16},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 1,
#    '5 stars': 0,
#    'avgScore': 22471.199999999877,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/apartment-hipster-kallio.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 0,
#    '5 stars': 2,
#    'avgScore': 11244.79999999994,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/punavuorenkatu-apartment-helsinki.html',
#    'reviewsNum': 4},
#   {'0 stars': 0,
#    '1 stars': 12,
#    '2 stars': 97,
#    '3 stars': 125,
#    '4 stars': 491,
#    '5 stars': 97,
#    'avgScore': 34.6819951338197,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/citykoti-apartments.html',
#    'reviewsNum': 850},
#   {'0 stars': 0,
#    '1 stars': 2,
#    '2 stars': 33,
#    '3 stars': 86,
#    '4 stars': 542,
#    '5 stars': 98,
#    'avgScore': 45.25821287779226,
#    'hotelStars': '2 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hotelli-finn.html',
#    'reviewsNum': 785},
#   {'0 stars': 0,
#    '1 stars': 5,
#    '2 stars': 30,
#    '3 stars': 76,
#    '4 stars': 239,
#    '5 stars': 50,
#    'avgScore': 93.46700000000024,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/cheapsleep-helsinki.html',
#    'reviewsNum': 431},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 8,
#    '3 stars': 27,
#    '4 stars': 84,
#    '5 stars': 20,
#    'avgScore': 276.60719424460575,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sokos-helsinki.html',
#    'reviewsNum': 148},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 2,
#    '3 stars': 18,
#    '4 stars': 75,
#    '5 stars': 15,
#    'avgScore': 357.43909090909347,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hostel-suomenlinna.html',
#    'reviewsNum': 119},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 10,
#    '5 stars': 8,
#    'avgScore': 2193.2277777777936,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/apartment-malmi.html',
#    'reviewsNum': 22},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 3,
#    '3 stars': 6,
#    '4 stars': 12,
#    '5 stars': 3,
#    'avgScore': 1651.9708333333456,
#    'hotelStars': '2 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kulttuurikeskus-sofia.html',
#    'reviewsNum': 27},
#   {'0 stars': 0,
#    '1 stars': 3,
#    '2 stars': 54,
#    '3 stars': 147,
#    '4 stars': 380,
#    '5 stars': 67,
#    'avgScore': 68.27496159754317,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/arthur.html',
#    'reviewsNum': 669},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 12,
#    '3 stars': 35,
#    '4 stars': 92,
#    '5 stars': 23,
#    'avgScore': 281.8783950617321,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hoildayinncitywest.html',
#    'reviewsNum': 170},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 4,
#    '3 stars': 14,
#    '4 stars': 40,
#    '5 stars': 10,
#    'avgScore': 679.3073529411863,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sokos-torni.html',
#    'reviewsNum': 75},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 5,
#    '4 stars': 7,
#    '5 stars': 2,
#    'avgScore': 3307.085714285763,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/gella-serviced-apartment-pita-ja-nma-ki.html',
#    'reviewsNum': 18},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 5,
#    '3 stars': 23,
#    '4 stars': 89,
#    '5 stars': 43,
#    'avgScore': 297.41687500000444,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/crowne-plaza-helsinki.html',
#    'reviewsNum': 172},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 0,
#    '5 stars': 0,
#    'avgScore': None,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/helsinki-city-centre.html',
#    'reviewsNum': 4},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 3,
#    '4 stars': 72,
#    '5 stars': 14,
#    'avgScore': 536.9166666666755,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/cumulus-meilahti.html',
#    'reviewsNum': 105},
#   {'0 stars': 0,
#    '1 stars': 6,
#    '2 stars': 15,
#    '3 stars': 88,
#    '4 stars': 240,
#    '5 stars': 75,
#    'avgScore': 121.62099056603994,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/scandic-continental.html',
#    'reviewsNum': 449},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 3,
#    '4 stars': 34,
#    '5 stars': 49,
#    'avgScore': 608.3255813953588,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/f6.html',
#    'reviewsNum': 186},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 2,
#    '4 stars': 3,
#    '5 stars': 2,
#    'avgScore': 7481.642857142979,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sea-pearl-apartment.html',
#    'reviewsNum': 9},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 4,
#    '4 stars': 27,
#    '5 stars': 37,
#    'avgScore': 778.8058823529527,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/essexhome-apartments-luotsikatu.html',
#    'reviewsNum': 129},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 30,
#    '3 stars': 107,
#    '4 stars': 357,
#    '5 stars': 55,
#    'avgScore': 103.84872727272935,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hostel-academica.html',
#    'reviewsNum': 561},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 4,
#    '3 stars': 3,
#    '4 stars': 35,
#    '5 stars': 5,
#    'avgScore': 1222.9957446808764,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/citykoti-downtown-suites-and-apartments.html',
#    'reviewsNum': 52},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 1,
#    '4 stars': 3,
#    '5 stars': 4,
#    'avgScore': 7193.350000000148,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/comodo-apartments-helsinki-west.html',
#    'reviewsNum': 10},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 1,
#    '5 stars': 1,
#    'avgScore': 28781.75000000059,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/eerikinkatu-apartament.html',
#    'reviewsNum': 4},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 4,
#    '5 stars': 3,
#    'avgScore': 8231.885714285881,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sleep-well-bb.html',
#    'reviewsNum': 8},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 1,
#    '4 stars': 5,
#    '5 stars': 1,
#    'avgScore': 8239.62857142874,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kesahostelli-karavaani.html',
#    'reviewsNum': 7},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 0,
#    '4 stars': 1,
#    '5 stars': 0,
#    'avgScore': 28845.60000000059,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/solakalliontie-row-house.html',
#    'reviewsNum': 4},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 3,
#    '4 stars': 2,
#    '5 stars': 0,
#    'avgScore': 9621.666666666863,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/toolonkatu-apartment.html',
#    'reviewsNum': 6},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 1,
#    '4 stars': 1,
#    '5 stars': 0,
#    'avgScore': 28871.90000000059,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/apartment-bjorklund.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 2,
#    '2 stars': 45,
#    '3 stars': 144,
#    '4 stars': 440,
#    '5 stars': 65,
#    'avgScore': 90.42528735632409,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/eurohostel.html',
#    'reviewsNum': 720},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 20,
#    '3 stars': 64,
#    '4 stars': 322,
#    '5 stars': 99,
#    'avgScore': 132.545544554459,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/scandic-simonkentta.html',
#    'reviewsNum': 513},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 4,
#    '3 stars': 29,
#    '4 stars': 228,
#    '5 stars': 116,
#    'avgScore': 185.3579365079409,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/scandic-paasi.html',
#    'reviewsNum': 431},
#   {'0 stars': 0,
#    '1 stars': 6,
#    '2 stars': 65,
#    '3 stars': 64,
#    '4 stars': 179,
#    '5 stars': 27,
#    'avgScore': 212.32404692082676,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/central-apartments.html',
#    'reviewsNum': 351},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 8,
#    '3 stars': 23,
#    '4 stars': 138,
#    '5 stars': 60,
#    'avgScore': 324.2493449781741,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/indigo-helsinki-boulevard.html',
#    'reviewsNum': 286},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 11,
#    '3 stars': 39,
#    '4 stars': 203,
#    '5 stars': 65,
#    'avgScore': 241.49119496855948,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/rivolijardin.html',
#    'reviewsNum': 334},
#   {'0 stars': 0,
#    '1 stars': 2,
#    '2 stars': 10,
#    '3 stars': 20,
#    '4 stars': 122,
#    '5 stars': 56,
#    'avgScore': 373.7461904761996,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/clarion-helsinki.html',
#    'reviewsNum': 243},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 2,
#    '3 stars': 4,
#    '4 stars': 33,
#    '5 stars': 12,
#    'avgScore': 1547.139215686312,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/private-apartments.html',
#    'reviewsNum': 58},
#   {'0 stars': 0,
#    '1 stars': 12,
#    '2 stars': 101,
#    '3 stars': 286,
#    '4 stars': 592,
#    '5 stars': 56,
#    'avgScore': 82.45281757402293,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/omenahotelli-helsinki-lapnnrotinkatu.html',
#    'reviewsNum': 1070},
#   {'0 stars': 0,
#    '1 stars': 2,
#    '2 stars': 24,
#    '3 stars': 41,
#    '4 stars': 152,
#    '5 stars': 24,
#    'avgScore': 362.6469135802557,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/best-western-carlton.html',
#    'reviewsNum': 245},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 5,
#    '5 stars': 1,
#    'avgScore': 14695.716666667024,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kallio-downtown-be-my-guest.html',
#    'reviewsNum': 7},
#   {'0 stars': 0,
#    '1 stars': 4,
#    '2 stars': 44,
#    '3 stars': 103,
#    '4 stars': 351,
#    '5 stars': 74,
#    'avgScore': 160.638020833337,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/seurahuone.html',
#    'reviewsNum': 602},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 5,
#    '3 stars': 13,
#    '4 stars': 40,
#    '5 stars': 6,
#    'avgScore': 1453.035937500034,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sokos-presidentti.html',
#    'reviewsNum': 67},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 0,
#    'avgScore': 46505.30000000109,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/urban-studio-apartment.html',
#    'reviewsNum': 4},
#   {'0 stars': 0,
#    '1 stars': 16,
#    '2 stars': 32,
#    '3 stars': 30,
#    '4 stars': 27,
#    '5 stars': 6,
#    'avgScore': 843.535135135155,
#    'hotelStars': '2 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/arkadia.html',
#    'reviewsNum': 115},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 7,
#    '3 stars': 20,
#    '4 stars': 170,
#    '5 stars': 48,
#    'avgScore': 390.19346938776397,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sweetdream-guesthouse.html',
#    'reviewsNum': 267},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 12,
#    '4 stars': 21,
#    '5 stars': 18,
#    'avgScore': 1882.621568627493,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/city-apartments.html',
#    'reviewsNum': 56},
#   {'0 stars': 0,
#    '1 stars': 2,
#    '2 stars': 1,
#    '3 stars': 6,
#    '4 stars': 104,
#    '5 stars': 56,
#    'avgScore': 576.4816568047462,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/lilla-roberts.html',
#    'reviewsNum': 231},
#   {'0 stars': 0,
#    '1 stars': 4,
#    '2 stars': 17,
#    '3 stars': 62,
#    '4 stars': 235,
#    '5 stars': 39,
#    'avgScore': 280.43725490196675,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/ava.html',
#    'reviewsNum': 363},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 3,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 0,
#    'avgScore': 20028.980000000425,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/studio-albertinkatu-close-to-centre.html',
#    'reviewsNum': 8},
#   {'0 stars': 0,
#    '1 stars': 3,
#    '2 stars': 3,
#    '3 stars': 12,
#    '4 stars': 43,
#    '5 stars': 16,
#    'avgScore': 1308.2922077922362,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/go-happy-home.html',
#    'reviewsNum': 103},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 0,
#    '5 stars': 2,
#    'avgScore': 50378.45000000109,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/apartment-with-urban-sea-view-and-sauna.html',
#    'reviewsNum': 5},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 33593.966666667395,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/merimiehenkatu-apartment.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 3,
#    '2 stars': 6,
#    '3 stars': 19,
#    '4 stars': 50,
#    '5 stars': 5,
#    'avgScore': 1221.485542168701,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kotimaailma-apartments-helsinki.html',
#    'reviewsNum': 85},
#   {'0 stars': 0,
#    '1 stars': 4,
#    '2 stars': 30,
#    '3 stars': 78,
#    '4 stars': 260,
#    '5 stars': 72,
#    'avgScore': 236.00405405405937,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/glo-hotel-art.html',
#    'reviewsNum': 470},
#   {'0 stars': 0,
#    '1 stars': 3,
#    '2 stars': 0,
#    '3 stars': 9,
#    '4 stars': 233,
#    '5 stars': 136,
#    'avgScore': 283.63280839895634,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/fabian.html',
#    'reviewsNum': 499},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 3,
#    '3 stars': 10,
#    '4 stars': 52,
#    '5 stars': 28,
#    'avgScore': 1170.1741935484122,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hilton-helsinki-strand.html',
#    'reviewsNum': 102},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 2,
#    '4 stars': 3,
#    '5 stars': 1,
#    'avgScore': 18145.616666667054,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/lomakoti.html',
#    'reviewsNum': 7},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 10,
#    '3 stars': 19,
#    '4 stars': 349,
#    '5 stars': 129,
#    'avgScore': 223.06094674556678,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/katajanokka.html',
#    'reviewsNum': 576},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 17,
#    '3 stars': 48,
#    '4 stars': 175,
#    '5 stars': 52,
#    'avgScore': 395.1013698630219,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/radisson-sas-royal-helsinki.html',
#    'reviewsNum': 308},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 2,
#    '4 stars': 1,
#    '5 stars': 2,
#    'avgScore': 23081.26000000048,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/helsinki-downtown-apartment.html',
#    'reviewsNum': 6},
#   {'0 stars': 0,
#    '1 stars': 5,
#    '2 stars': 71,
#    '3 stars': 129,
#    '4 stars': 314,
#    '5 stars': 31,
#    'avgScore': 216.92000000000473,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/omenahotelli-helsinki-citycentre.html',
#    'reviewsNum': 560},
#   {'0 stars': 0,
#    '1 stars': 6,
#    '2 stars': 10,
#    '3 stars': 20,
#    '4 stars': 110,
#    '5 stars': 39,
#    'avgScore': 652.5589189189328,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hilton-helsinki-kalastajatorppa.html',
#    'reviewsNum': 207},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 5,
#    '4 stars': 6,
#    '5 stars': 1,
#    'avgScore': 9293.80769230789,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/apartment-elias.html',
#    'reviewsNum': 14},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 12,
#    '3 stars': 63,
#    '4 stars': 187,
#    '5 stars': 48,
#    'avgScore': 397.405483870976,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/accome-apartments-senate.html',
#    'reviewsNum': 320},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 4,
#    '3 stars': 3,
#    '4 stars': 5,
#    '5 stars': 1,
#    'avgScore': 9483.130769230967,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/villa-helsingfors.html',
#    'reviewsNum': 18},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 1,
#    '4 stars': 1,
#    '5 stars': 1,
#    'avgScore': 41101.36666666752,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/ullis-pearl-apartment.html',
#    'reviewsNum': 4},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 0,
#    '5 stars': 0,
#    'avgScore': None,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/helsinki-south-central-apartment-studio.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 5,
#    '3 stars': 20,
#    '4 stars': 113,
#    '5 stars': 19,
#    'avgScore': 793.2114649681693,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/cumulus-hakaniemi.html',
#    'reviewsNum': 168},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 3,
#    '3 stars': 1,
#    '4 stars': 12,
#    '5 stars': 8,
#    'avgScore': 5196.995833333439,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/studio-apartment.html',
#    'reviewsNum': 33},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 20,
#    '3 stars': 88,
#    '4 stars': 214,
#    '5 stars': 39,
#    'avgScore': 352.02237569061515,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/scandic-marski.html',
#    'reviewsNum': 376},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 1,
#    '4 stars': 2,
#    '5 stars': 0,
#    'avgScore': 42485.33333333423,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/garden-house-b-b.html',
#    'reviewsNum': 6},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 4,
#    '3 stars': 3,
#    '4 stars': 9,
#    '5 stars': 1,
#    'avgScore': 7087.327777777928,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/4pillowsapartments-tyomiehenkatu.html',
#    'reviewsNum': 19},
#   {'0 stars': 0,
#    '1 stars': 3,
#    '2 stars': 4,
#    '3 stars': 41,
#    '4 stars': 193,
#    '5 stars': 49,
#    'avgScore': 447.7620689655268,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sato-hotelhome.html',
#    'reviewsNum': 323},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 4,
#    '3 stars': 6,
#    '4 stars': 24,
#    '5 stars': 10,
#    'avgScore': 2958.9068181818807,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/apartments-next-rivoli-jardin.html',
#    'reviewsNum': 46},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 6,
#    '4 stars': 17,
#    '5 stars': 2,
#    'avgScore': 5015.0076923077995,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sokos-pasila.html',
#    'reviewsNum': 26},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 4,
#    '5 stars': 2,
#    'avgScore': 21740.41666666713,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/huoneistohotelli-eskolampi.html',
#    'reviewsNum': 7},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 12,
#    '3 stars': 48,
#    '4 stars': 183,
#    '5 stars': 19,
#    'avgScore': 503.5114068441147,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/cumulus-kaisaniemi.html',
#    'reviewsNum': 274},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 2,
#    '3 stars': 0,
#    '4 stars': 5,
#    '5 stars': 0,
#    'avgScore': 18924.800000000305,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/experience-living-apartments.html',
#    'reviewsNum': 13},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 2,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 0,
#    'avgScore': 33125.10000000053,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/apartment-koydenpunojankatu-helsinki.html',
#    'reviewsNum': 6},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 44174.43333333404,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/uman-city-studio-flemingsgatan.html',
#    'reviewsNum': 4},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 3,
#    '4 stars': 7,
#    '5 stars': 0,
#    'avgScore': 13260.130000000205,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/helsinki-apartment.html',
#    'reviewsNum': 11},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 3,
#    '5 stars': 2,
#    'avgScore': 26529.020000000408,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/apartment-savela.html',
#    'reviewsNum': 9},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 1,
#    '4 stars': 2,
#    '5 stars': 0,
#    'avgScore': 44222.66666666733,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/pietarinkatu-apartment.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 1,
#    '4 stars': 6,
#    '5 stars': 1,
#    'avgScore': 14748.388888889109,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/apartment-herttoniemi.html',
#    'reviewsNum': 10},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 5,
#    '3 stars': 6,
#    '4 stars': 9,
#    '5 stars': 0,
#    'avgScore': 6326.995238095332,
#    'hotelStars': '2 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/forenom-hostel-helsinki-merihaka-helsinki9.html',
#    'reviewsNum': 21},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 3,
#    '3 stars': 27,
#    '4 stars': 89,
#    '5 stars': 33,
#    'avgScore': 881.9585526315905,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sokos-vaakuna-helsinki.html',
#    'reviewsNum': 157},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 10,
#    '3 stars': 4,
#    '4 stars': 8,
#    '5 stars': 1,
#    'avgScore': 5834.591304347901,
#    'hotelStars': '2 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/forenom-helsinki.html',
#    'reviewsNum': 24},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 8,
#    '3 stars': 9,
#    '4 stars': 38,
#    '5 stars': 13,
#    'avgScore': 1952.3289855072685,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/toolo-towers.html',
#    'reviewsNum': 80},
#   {'0 stars': 0,
#    '1 stars': 2,
#    '2 stars': 2,
#    '3 stars': 4,
#    '4 stars': 2,
#    '5 stars': 0,
#    'avgScore': 13476.640000000154,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/4pillowsapartments-kalevankatu.html',
#    'reviewsNum': 12},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 0,
#    'avgScore': 67391.75000000076,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sleep-well-apartments.html',
#    'reviewsNum': 4},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 4,
#    '3 stars': 3,
#    '4 stars': 8,
#    '5 stars': 2,
#    'avgScore': 7935.247058823619,
#    'hotelStars': '2 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/forenom-hostel-helsinki.html',
#    'reviewsNum': 19},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 42,
#    '3 stars': 96,
#    '4 stars': 399,
#    '5 stars': 85,
#    'avgScore': 224.5271704180065,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/scandic-grand-marina.html',
#    'reviewsNum': 649},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 13,
#    '3 stars': 64,
#    '4 stars': 282,
#    '5 stars': 113,
#    'avgScore': 303.9292372881343,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/radisson-sas-plaza.html',
#    'reviewsNum': 542},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 1,
#    'avgScore': 47826.83333333313,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/alppila-apartment.html',
#    'reviewsNum': 4},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 18,
#    '3 stars': 64,
#    '4 stars': 329,
#    '5 stars': 92,
#    'avgScore': 293.1071570576509,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hostel-erottajanpuisto.html',
#    'reviewsNum': 518},
#   {'0 stars': 0,
#    '1 stars': 3,
#    '2 stars': 17,
#    '3 stars': 41,
#    '4 stars': 197,
#    '5 stars': 71,
#    'avgScore': 455.9343465045534,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/hotel-haaga-central-park.html',
#    'reviewsNum': 337},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 8,
#    '3 stars': 37,
#    '4 stars': 355,
#    '5 stars': 91,
#    'avgScore': 313.7421588594645,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sato-hotelhome-kristianinkatu.html',
#    'reviewsNum': 519},
#   {'0 stars': 0,
#    '1 stars': 2,
#    '2 stars': 9,
#    '3 stars': 17,
#    '4 stars': 102,
#    '5 stars': 46,
#    'avgScore': 883.2999999999818,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/holiday-inn-helsinki-city-centre.html',
#    'reviewsNum': 200},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 0,
#    '5 stars': 5,
#    'avgScore': 31101.359999999368,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/wonderful-haaga-apartment.html',
#    'reviewsNum': 7},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 4,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 0,
#    'avgScore': 25923.799999999475,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kamppi-residence.html',
#    'reviewsNum': 7},
#   {'0 stars': 0,
#    '1 stars': 2,
#    '2 stars': 15,
#    '3 stars': 65,
#    '4 stars': 293,
#    '5 stars': 88,
#    'avgScore': 343.8131749459955,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/helkahelsinki.html',
#    'reviewsNum': 490},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 1,
#    '5 stars': 1,
#    'avgScore': 79601.74999999796,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/apartment-lauttasaari.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 4,
#    '3 stars': 6,
#    '4 stars': 20,
#    '5 stars': 7,
#    'avgScore': 4310.448648648536,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sokos-albert.html',
#    'reviewsNum': 37},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 1,
#    '4 stars': 1,
#    '5 stars': 0,
#    'avgScore': 79750.5999999979,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/sweet-home-bulevardi-12.html',
#    'reviewsNum': 4},
#   {'0 stars': 0,
#    '1 stars': 2,
#    '2 stars': 7,
#    '3 stars': 72,
#    '4 stars': 259,
#    '5 stars': 91,
#    'avgScore': 378.02412993038183,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/klaus-k.html',
#    'reviewsNum': 464},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 0,
#    'avgScore': 81472.09999999728,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/fresh-studio-center-helsinki.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 2,
#    '3 stars': 3,
#    '4 stars': 14,
#    '5 stars': 5,
#    'avgScore': 6797.07916666644,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kapyla.html',
#    'reviewsNum': 31},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 2,
#    '3 stars': 0,
#    '4 stars': 2,
#    '5 stars': 0,
#    'avgScore': 40788.69999999864,
#    'hotelStars': None,
#    'hotelUrl': 'https://www.booking.com/hotel/fi/malminkatu-apartment.html',
#    'reviewsNum': 5},
#   {'0 stars': 0,
#    '1 stars': 1,
#    '2 stars': 3,
#    '3 stars': 3,
#    '4 stars': 72,
#    '5 stars': 63,
#    'avgScore': 1157.4725352112307,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/haven.html',
#    'reviewsNum': 170},
#   {'0 stars': 0,
#    '1 stars': 2,
#    '2 stars': 16,
#    '3 stars': 35,
#    '4 stars': 87,
#    '5 stars': 18,
#    'avgScore': 1047.4797468354088,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/forenom-house-helsinki.html',
#    'reviewsNum': 164},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 7,
#    '3 stars': 7,
#    '4 stars': 42,
#    '5 stars': 1,
#    'avgScore': 2910.9421052630564,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/rastila-camping.html',
#    'reviewsNum': 59},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 0,
#    '3 stars': 0,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 55315.56666666474,
#    'hotelStars': '5 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/kaivopuiston-tahti.html',
#    'reviewsNum': 3},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 1,
#    '3 stars': 1,
#    '4 stars': 3,
#    '5 stars': 0,
#    'avgScore': 33196.09999999884,
#    'hotelStars': '2 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/budget-apartments.html',
#    'reviewsNum': 5},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 5,
#    '3 stars': 10,
#    '4 stars': 28,
#    '5 stars': 2,
#    'avgScore': 3695.797777777645,
#    'hotelStars': '4 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/innhelsinki.html',
#    'reviewsNum': 48},
#   {'0 stars': 0,
#    '1 stars': 0,
#    '2 stars': 14,
#    '3 stars': 34,
#    '4 stars': 52,
#    '5 stars': 14,
#    'avgScore': 1465.8912280701225,
#    'hotelStars': '3 stars',
#    'hotelUrl': 'https://www.booking.com/hotel/fi/cumulus-kallio.html',
#    'reviewsNum': 120}],
#  'maxReviewNumAHotel': 1070,
#  'minReviewNumAHotel': 3,
#  'null stars': 1842,
#  'totalHotels': 137,
#  'totalReviews': 23572}

# %%
with open("005_statistics_booking_Helsinki_tripadvisor.json", "w") as f:
    json.dump(statistics, f)
    f.close()
